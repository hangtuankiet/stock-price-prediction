# %% [markdown]
#  # Bước 1: Import thư viện

# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trung bình

# %% [markdown]
# # Bước 2: Đọc dữ liệu

# %%
df = pd.read_excel('../Assest/data/dulieu.xlsx')

# %%
#dữ liệu 5 dòng đầu
df.head()
# Out:
#    Unnamed: 0       time   open   high    low  close   volume          MA50  \
# 0           0 2013-01-02  19640  19790  19590  19790    90770  19790.000000
# 1           1 2013-01-03  19790  20040  19690  19790  1618510  19790.000000
# 2           2 2013-01-04  20150  20400  19790  20250  1318980  19943.333333
# 3           3 2013-01-07  20400  20450  20250  20250   701600  20020.000000
# 4           4 2013-01-08  20190  21010  20100  20700   871680  20156.000000
#
#           MA200  sup  Buy_signal  Sell_signal
# 0  19790.000000  0.0           0            0
# 1  19790.000000  NaN           0            0
# 2  19943.333333  NaN           0            0
# 3  20020.000000  NaN           0            0
# 4  20156.000000  NaN           0            0

# %% [markdown]
# # Bước 3: Mô tả dữ liệu

# %%
#định dạng cấu trúc thời gian
df["time"] = pd.to_datetime(df.time, format="%Y-%m-%d")

#kích thước dữ liệu
df.shape

#xác định kiểu dữ liệu
df.info()

#mô tả bộ dữ liệu
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2800 non-null   int64
#  1   time         2800 non-null   datetime64[ns]
#  2   open         2800 non-null   int64
#  3   high         2800 non-null   int64
#  4   low          2800 non-null   int64
#  5   close        2800 non-null   int64
#  6   volume       2800 non-null   int64
#  7   MA50         2800 non-null   float64
#  8   MA200        2800 non-null   float64
#  9   sup          2794 non-null   float64
#  10  Buy_signal   2800 non-null   int64
#  11  Sell_signal  2800 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 262.6 KB
#         Unnamed: 0                 time           open           high  \
# count  2800.000000                 2800    2800.000000    2800.000000
# mean   1399.500000  2018-08-17 15:54:00   57771.999286   58543.263571
# min       0.000000  2013-01-02 00:00:00   17380.000000   17720.000000
# 25%     699.750000  2015-10-29 18:00:00   37770.000000   38310.000000
# 50%    1399.500000  2018-08-18 12:00:00   59820.000000   60700.000000
# 75%    2099.250000  2021-06-08 06:00:00   75685.000000   76402.500000
# max    2799.000000  2024-03-25 00:00:00  102560.000000  104910.000000
# std     808.434702                  NaN   20811.229597   21125.291534
#
#                  low          close        volume         MA50         MA200  \
# count    2800.000000    2800.000000  2.800000e+03   2800.00000   2800.000000
# mean    57001.083571   57716.315714  6.153748e+05  57213.62448  55744.291734
# min     17210.000000   17320.000000  3.086000e+04  19790.00000  19790.000000
# 25%     37400.000000   37770.000000  2.963550e+05  37667.58500  37717.075000
# 50%     58730.000000   59820.000000  5.044500e+05  59823.02000  56097.460000
# 75%     74882.500000   75520.000000  7.908750e+05  75226.00000  71702.202500
# max    100440.000000  104910.000000  4.515800e+06  89808.20000  88514.550000
# std     20486.579832   20781.400694  4.637070e+05  20613.79648  20078.883386
#
#                  sup   Buy_signal  Sell_signal
# count    2794.000000  2800.000000  2800.000000
# mean    57861.749067     0.012857     0.012857
# min         0.000000     0.000000     0.000000
# 25%     38247.325359     0.000000     0.000000
# 50%     60606.965419     0.000000     0.000000
# 75%     76397.042571     0.000000     0.000000
# max    109698.097222     1.000000     1.000000
# std     21260.338648     0.112678     0.112678

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2800 non-null   int64
#  1   time         2800 non-null   datetime64[ns]
#  2   open         2800 non-null   int64
#  3   high         2800 non-null   int64
#  4   low          2800 non-null   int64
#  5   close        2800 non-null   int64
#  6   volume       2800 non-null   int64
#  7   MA50         2800 non-null   float64
#  8   MA200        2800 non-null   float64
#  9   sup          2794 non-null   float64
#  10  Buy_signal   2800 non-null   int64
#  11  Sell_signal  2800 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 262.6 KB

# %% [markdown]
# # Bước 4: Tiền xử lý dữ liệu

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator


# Sắp xếp lại dữ liệu theo thứ tự thời gian
df = df.sort_values(by='time')

# Tạo đồ thị giá đóng cửa, giá mở cửa, giá cao nhất, và giá thấp nhất qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['time'], df['close'], label='Giá đóng cửa', color='red')
plt.plot(df['time'], df['open'], label='Giá mở cửa', color='green')
plt.plot(df['time'], df['high'], label='Giá cao nhất', color='blue')
plt.plot(df['time'], df['low'], label='Giá thấp nhất', color='orange')

plt.xlabel('Năm')
plt.ylabel('Giá')
plt.title('Biểu đồ giá qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y-%m')
months = MonthLocator()
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
df1 = pd.DataFrame(df,columns=['time','close', 'open', 'high', 'low'])
df1.index = df1.time
df1.drop('time',axis=1,inplace=True)
df1
# Out:
#             close   open   high    low
# time
# 2013-01-02  19790  19640  19790  19590
# 2013-01-03  19790  19790  20040  19690
# 2013-01-04  20250  20150  20400  19790
# 2013-01-07  20250  20400  20450  20250
# 2013-01-08  20700  20190  21010  20100
# ...           ...    ...    ...    ...
# 2024-03-19  79700  81000  81000  79700
# 2024-03-20  81000  80000  81200  79600
# 2024-03-21  81000  81900  81900  80500
# 2024-03-22  80500  81000  81500  80400
# 2024-03-25  80400  80500  81400  80100
#
# [2800 rows x 4 columns]

# %%
#chia tập dữ liệu
data = df1.values
train_data = data[:1500]
test_data = data[1500:]

# %%
data
# Out:
# array([[19790, 19640, 19790, 19590],
#        [19790, 19790, 20040, 19690],
#        [20250, 20150, 20400, 19790],
#        ...,
#        [81000, 81900, 81900, 80500],
#        [80500, 81000, 81500, 80400],
#        [80400, 80500, 81400, 80100]], dtype=int64)

# %%
#chuẩn hóa dữ liệu

sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)  # Chỉ sử dụng train_data để fit scaler

# %%
#tạo vòng lặp các giá trị
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i-50:i, 0:4])  # Lấy 50 giá trị liên tiếp, bao gồm cả close và open, high, low
    y_train.append(sc_train[i, 0:4])  # Lấy ra giá close và open, high, low ngày hôm sau

# %%
# x_train
# y_train

# %%
#xếp dữ liệu thành 1 mảng 2 chiều
x_train = np.array(x_train)
y_train = np.array(y_train)

#xếp lại dữ liệu thành mảng 1 chiều
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],4))
y_train = np.reshape(y_train,(y_train.shape[0],4))

# %% [markdown]
# # Bước 5: Xây dựng và huấn luyện mô hình

# %%
# Xây dựng mô hình
model = Sequential()  # Tạo lớp mạng cho dữ liệu đầu vào

# Thêm 2 lớp LSTM mới, tổng cộng là 3 lớp LSTM với tham số return_sequences=True
model.add(LSTM(units=128, input_shape=(x_train.shape[1], 4), return_sequences=True))
model.add(Dropout(0.2))  # Thêm Dropout để giảm overfitting sau mỗi lớp LSTM

model.add(LSTM(units=128, return_sequences=True))
model.add(Dropout(0.2))  # Thêm Dropout

model.add(LSTM(units=128, return_sequences=True))
model.add(Dropout(0.2))  # Thêm Dropout

# Lớp LSTM cuối cùng không cần tham số return_sequences vì đây là lớp cuối trước khi kết nối với Dense layer
model.add(LSTM(units=64))
model.add(Dropout(0.5))  # Giữ nguyên Dropout như lớp LSTM cuối cũ trong mô hình ban đầu

model.add(Dense(4))  # Output đầu ra 1 chiều

# Đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa adam
model.compile(loss='mean_absolute_error', optimizer='adam')
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#huấn luyện mô hình
save_model = "../model/models3.keras"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')
model.fit(x_train,y_train,epochs=100,batch_size=50,verbose=2,callbacks=[best_model])
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.10200, saving model to ../model/models3.keras
# 29/29 - 5s - 169ms/step - loss: 0.1020
# Epoch 2/100
#
# Epoch 2: loss improved from 0.10200 to 0.07138, saving model to ../model/models3.keras
# 29/29 - 2s - 71ms/step - loss: 0.0714
# Epoch 3/100
#
# Epoch 3: loss improved from 0.07138 to 0.06472, saving model to ../model/models3.keras
# 29/29 - 2s - 73ms/step - loss: 0.0647
# Epoch 4/100
#
# Epoch 4: loss improved from 0.06472 to 0.05727, saving model to ../model/models3.keras
# 29/29 - 2s - 78ms/step - loss: 0.0573
# Epoch 5/100
#
# Epoch 5: loss improved from 0.05727 to 0.05309, saving model to ../model/models3.keras
# 29/29 - 2s - 68ms/step - loss: 0.0531
# Epoch 6/100
#
# Epoch 6: loss improved from 0.05309 to 0.05129, saving model to ../model/models3.keras
# 29/29 - 2s - 65ms/step - loss: 0.0513
# Epoch 7/100
#
# Epoch 7: loss improved from 0.05129 to 0.04805, saving model to ../model/models3.keras
# 29/29 - 2s - 69ms/step - loss: 0.0480
# Epoch 8/100
#
# Epoch 8: loss improved from 0.04805 to 0.04413, saving model to ../model/models3.keras
# 29/29 - 2s - 66ms/step - loss: 0.0441
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.04413
# 29/29 - 2s - 63ms/step - loss: 0.0441
# Epoch 10/100
#
# Epoch 10: loss improved from 0.04413 to 0.04134, saving model to ../model/models3.keras
# 29/29 - 2s - 68ms/step - loss: 0.0413
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04134 to 0.03977, saving model to ../model/models3.keras
# 29/29 - 2s - 66ms/step - loss: 0.0398
# Epoch 12/100
#
# Epoch 12: loss improved from 0.03977 to 0.03754, saving model to ../model/models3.keras
# 29/29 - 2s - 74ms/step - loss: 0.0375
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.03754
# 29/29 - 2s - 71ms/step - loss: 0.0377
# Epoch 14/100
#
# Epoch 14: loss improved from 0.03754 to 0.03445, saving model to ../model/models3.keras
# 29/29 - 2s - 68ms/step - loss: 0.0345
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03445 to 0.03405, saving model to ../model/models3.keras
# 29/29 - 2s - 71ms/step - loss: 0.0340
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.03405
# 29/29 - 2s - 78ms/step - loss: 0.0357
# Epoch 17/100
#
# Epoch 17: loss improved from 0.03405 to 0.03334, saving model to ../model/models3.keras
# 29/29 - 3s - 90ms/step - loss: 0.0333
# Epoch 18/100
#
# Epoch 18: loss improved from 0.03334 to 0.03250, saving model to ../model/models3.keras
# 29/29 - 3s - 90ms/step - loss: 0.0325
# Epoch 19/100
#
# Epoch 19: loss improved from 0.03250 to 0.03002, saving model to ../model/models3.keras
# 29/29 - 2s - 84ms/step - loss: 0.0300
# Epoch 20/100
#
# Epoch 20: loss improved from 0.03002 to 0.02984, saving model to ../model/models3.keras
# 29/29 - 2s - 73ms/step - loss: 0.0298
# Epoch 21/100
#
# Epoch 21: loss improved from 0.02984 to 0.02911, saving model to ../model/models3.keras
# 29/29 - 2s - 68ms/step - loss: 0.0291
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.02911
# 29/29 - 2s - 67ms/step - loss: 0.0293
# Epoch 23/100
#
# Epoch 23: loss improved from 0.02911 to 0.02827, saving model to ../model/models3.keras
# 29/29 - 2s - 66ms/step - loss: 0.0283
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.02827
# 29/29 - 2s - 67ms/step - loss: 0.0284
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02827 to 0.02724, saving model to ../model/models3.keras
# 29/29 - 2s - 65ms/step - loss: 0.0272
# Epoch 26/100
#
# Epoch 26: loss improved from 0.02724 to 0.02619, saving model to ../model/models3.keras
# 29/29 - 2s - 64ms/step - loss: 0.0262
# Epoch 27/100
#
# Epoch 27: loss improved from 0.02619 to 0.02556, saving model to ../model/models3.keras
# 29/29 - 2s - 70ms/step - loss: 0.0256
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.02556
# 29/29 - 2s - 71ms/step - loss: 0.0265
# Epoch 29/100
#
# Epoch 29: loss improved from 0.02556 to 0.02540, saving model to ../model/models3.keras
# 29/29 - 2s - 67ms/step - loss: 0.0254
# Epoch 30/100
#
# Epoch 30: loss improved from 0.02540 to 0.02527, saving model to ../model/models3.keras
# 29/29 - 2s - 67ms/step - loss: 0.0253
# Epoch 31/100
#
# Epoch 31: loss improved from 0.02527 to 0.02487, saving model to ../model/models3.keras
# 29/29 - 2s - 64ms/step - loss: 0.0249
# Epoch 32/100
#
# Epoch 32: loss improved from 0.02487 to 0.02445, saving model to ../model/models3.keras
# 29/29 - 2s - 65ms/step - loss: 0.0245
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.02445
# 29/29 - 2s - 63ms/step - loss: 0.0256
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.02445
# 29/29 - 2s - 64ms/step - loss: 0.0252
# Epoch 35/100
#
# Epoch 35: loss improved from 0.02445 to 0.02405, saving model to ../model/models3.keras
# 29/29 - 2s - 75ms/step - loss: 0.0241
# Epoch 36/100
#
# Epoch 36: loss improved from 0.02405 to 0.02393, saving model to ../model/models3.keras
# 29/29 - 2s - 76ms/step - loss: 0.0239
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.02393
# 29/29 - 2s - 79ms/step - loss: 0.0241
# Epoch 38/100
#
# Epoch 38: loss improved from 0.02393 to 0.02347, saving model to ../model/models3.keras
# 29/29 - 2s - 79ms/step - loss: 0.0235
# Epoch 39/100
#
# Epoch 39: loss improved from 0.02347 to 0.02273, saving model to ../model/models3.keras
# 29/29 - 2s - 83ms/step - loss: 0.0227
# Epoch 40/100
#
# Epoch 40: loss improved from 0.02273 to 0.02219, saving model to ../model/models3.keras
# 29/29 - 2s - 77ms/step - loss: 0.0222
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.02219
# 29/29 - 2s - 80ms/step - loss: 0.0245
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.02219
# 29/29 - 2s - 77ms/step - loss: 0.0229
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.02219
# 29/29 - 2s - 76ms/step - loss: 0.0227
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.02219
# 29/29 - 2s - 81ms/step - loss: 0.0226
# Epoch 45/100
#
# Epoch 45: loss improved from 0.02219 to 0.02214, saving model to ../model/models3.keras
# 29/29 - 2s - 81ms/step - loss: 0.0221
# Epoch 46/100
#
# Epoch 46: loss improved from 0.02214 to 0.02213, saving model to ../model/models3.keras
# 29/29 - 2s - 79ms/step - loss: 0.0221
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.02213
# 29/29 - 2s - 78ms/step - loss: 0.0234
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.02213
# 29/29 - 2s - 77ms/step - loss: 0.0230
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.02213
# 29/29 - 2s - 76ms/step - loss: 0.0240
# Epoch 50/100
#
# Epoch 50: loss improved from 0.02213 to 0.02164, saving model to ../model/models3.keras
# 29/29 - 2s - 76ms/step - loss: 0.0216
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.02164
# 29/29 - 2s - 79ms/step - loss: 0.0225
# Epoch 52/100
#
# Epoch 52: loss improved from 0.02164 to 0.02136, saving model to ../model/models3.keras
# 29/29 - 2s - 80ms/step - loss: 0.0214
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.02136
# 29/29 - 2s - 78ms/step - loss: 0.0219
# Epoch 54/100
#
# Epoch 54: loss improved from 0.02136 to 0.02091, saving model to ../model/models3.keras
# 29/29 - 2s - 81ms/step - loss: 0.0209
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.02091
# 29/29 - 2s - 82ms/step - loss: 0.0211
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.02091
# 29/29 - 2s - 79ms/step - loss: 0.0231
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.02091
# 29/29 - 2s - 76ms/step - loss: 0.0222
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.02091
# 29/29 - 2s - 80ms/step - loss: 0.0210
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.02091
# 29/29 - 2s - 82ms/step - loss: 0.0214
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.02091
# 29/29 - 2s - 85ms/step - loss: 0.0215
# Epoch 61/100
#
# Epoch 61: loss improved from 0.02091 to 0.02085, saving model to ../model/models3.keras
# 29/29 - 2s - 86ms/step - loss: 0.0209
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.02085
# 29/29 - 2s - 80ms/step - loss: 0.0217
# Epoch 63/100
#
# Epoch 63: loss improved from 0.02085 to 0.02052, saving model to ../model/models3.keras
# 29/29 - 2s - 82ms/step - loss: 0.0205
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.02052
# 29/29 - 2s - 79ms/step - loss: 0.0219
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.02052
# 29/29 - 2s - 83ms/step - loss: 0.0220
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.02052
# 29/29 - 2s - 78ms/step - loss: 0.0218
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.02052
# 29/29 - 2s - 80ms/step - loss: 0.0207
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02052
# 29/29 - 2s - 81ms/step - loss: 0.0208
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.02052
# 29/29 - 2s - 81ms/step - loss: 0.0205
# Epoch 70/100
#
# Epoch 70: loss improved from 0.02052 to 0.02018, saving model to ../model/models3.keras
# 29/29 - 2s - 79ms/step - loss: 0.0202
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02018
# 29/29 - 2s - 73ms/step - loss: 0.0208
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02018
# 29/29 - 2s - 78ms/step - loss: 0.0204
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02018
# 29/29 - 2s - 78ms/step - loss: 0.0213
# Epoch 74/100
#
# Epoch 74: loss improved from 0.02018 to 0.02009, saving model to ../model/models3.keras
# 29/29 - 2s - 84ms/step - loss: 0.0201
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.02009
# 29/29 - 2s - 76ms/step - loss: 0.0209
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02009
# 29/29 - 2s - 76ms/step - loss: 0.0202
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02009
# 29/29 - 2s - 72ms/step - loss: 0.0209
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02009
# 29/29 - 2s - 75ms/step - loss: 0.0203
# Epoch 79/100
#
# Epoch 79: loss improved from 0.02009 to 0.02007, saving model to ../model/models3.keras
# 29/29 - 2s - 77ms/step - loss: 0.0201
# Epoch 80/100
#
# Epoch 80: loss improved from 0.02007 to 0.02005, saving model to ../model/models3.keras
# 29/29 - 2s - 78ms/step - loss: 0.0200
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.02005
# 29/29 - 2s - 76ms/step - loss: 0.0213
# Epoch 82/100
#
# Epoch 82: loss improved from 0.02005 to 0.01936, saving model to ../model/models3.keras
# 29/29 - 2s - 79ms/step - loss: 0.0194
# Epoch 83/100
#
# Epoch 83: loss improved from 0.01936 to 0.01922, saving model to ../model/models3.keras
# 29/29 - 2s - 75ms/step - loss: 0.0192
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01922
# 29/29 - 2s - 78ms/step - loss: 0.0207
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0205
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0212
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0198
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01922
# 29/29 - 2s - 77ms/step - loss: 0.0198
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0195
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0207
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01922
# 29/29 - 2s - 81ms/step - loss: 0.0198
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01922
# 29/29 - 2s - 77ms/step - loss: 0.0197
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0194
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01922
# 29/29 - 2s - 75ms/step - loss: 0.0194
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01922
# 29/29 - 2s - 78ms/step - loss: 0.0199
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01922
# 29/29 - 2s - 76ms/step - loss: 0.0197
# Epoch 97/100
#
# Epoch 97: loss improved from 0.01922 to 0.01899, saving model to ../model/models3.keras
# 29/29 - 2s - 78ms/step - loss: 0.0190
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01899
# 29/29 - 2s - 79ms/step - loss: 0.0194
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01899
# 29/29 - 2s - 76ms/step - loss: 0.0197
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01899
# 29/29 - 2s - 76ms/step - loss: 0.0200

# %%
#dữ liệu train
y_train = sc.inverse_transform(y_train) #giá thực
final_model = load_model("../model/models3.keras")
y_train_predict = final_model.predict(x_train) #dự đoán giá đóng cửa trên tập đã train
y_train_predict = sc.inverse_transform(y_train_predict) #giá dự đoán
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %% [markdown]
# # Bước 6: Tái sử dụng mô hình

# %%
# Xử lý dữ liệu test
test = df1[len(train_data)-50:].values  # Lấy dữ liệu test với cả hai cột

# Sử dụng MinMaxScaler đã được fit với cả hai cột để biến đổi
sc_test = sc.transform(test)

x_test, y_test = [], []
for i in range(50, test.shape[0]):
    x_test.append(sc_test[i-50:i])
x_test = np.array(x_test)

# Đối với mô hình LSTM, dữ liệu đầu vào cần được reshape thành [samples, time steps, features]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 4))

# Sau đó, bạn có thể sử dụng mô hình để dự đoán
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)  # Chuyển dữ liệu dự đoán về dạng ban đầu
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %% [markdown]
# # Độ chính xác của mô hình

# %%
# Chuẩn bị dữ liệu cho việc vẽ biểu đồ
train_data1 = df1.iloc[50:1500].copy()  # Sử dụng .copy() để tránh cảnh báo SettingWithCopy
test_data1 = df1.iloc[1500:].copy()

# Cập nhật DataFrame với dữ liệu dự đoán
train_data1['Dự đoán Close'] = y_train_predict[:, 0]  # Cột đầu tiên cho 'close'
train_data1['Dự đoán Open'] = y_train_predict[:, 1]  # Cột thứ hai cho 'open'

test_data1['Dự đoán Close'] = y_test_predict[:, 0]  # Tương tự cho dữ liệu kiểm tra
test_data1['Dự đoán Open'] = y_test_predict[:, 1]

train_data1['Dự đoán High'] = y_train_predict[:, 2]  # Cột thứ 3 cho 'high'
train_data1['Dự đoán Low'] = y_train_predict[:, 3]  # Cột thứ 4 cho 'low'

test_data1['Dự đoán High'] = y_test_predict[:, 2]  # Tương tự cho dữ liệu kiểm tra
test_data1['Dự đoán Low'] = y_test_predict[:, 3]

plt.figure(figsize=(24,8))

# Vẽ giá 'close' và 'open' thực tế
plt.plot(df1.index, df1['close'], label='Giá đóng cửa thực tế', color='red', alpha=0.5)
plt.plot(df1.index, df1['open'], label='Giá mở cửa thực tế', color='blue', alpha=0.5)
plt.plot(df1.index, df1['high'], label='Giá cao nhất thực tế', color='green', alpha=0.5)
plt.plot(df1.index, df1['low'], label='Giá thấp nhất thực tế', color='orange', alpha=0.5)

# Vẽ giá dự đoán 'close' và 'open' cho dữ liệu huấn luyện và kiểm tra
plt.plot(train_data1.index, train_data1['Dự đoán Close'], label='Giá đóng cửa dự đoán train', color='red', linestyle='--')
plt.plot(train_data1.index, train_data1['Dự đoán Open'], label='Giá mở cửa dự đoán train', color='blue', linestyle='--')

plt.plot(test_data1.index, test_data1['Dự đoán Close'], label='Giá đóng cửa dự đoán test', color='red', linestyle='-.')
plt.plot(test_data1.index, test_data1['Dự đoán Open'], label='Giá mở cửa dự đoán test', color='blue', linestyle='-.')

plt.plot(train_data1.index, train_data1['Dự đoán High'], label='Giá đóng cửa dự đoán train', color='green', linestyle='--')
plt.plot(train_data1.index, train_data1['Dự đoán Low'], label='Giá mở cửa dự đoán train', color='orange', linestyle='--')

plt.plot(test_data1.index, test_data1['Dự đoán High'], label='Giá đóng cửa dự đoán test', color='green', linestyle='-.')
plt.plot(test_data1.index, test_data1['Dự đoán Low'], label='Giá mở cửa dự đoán test', color='orange', linestyle='-.')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá (VNĐ)')
plt.legend()
plt.show()

# %%
# Đánh giá cho 'close'
print('Đánh giá cho giá đóng cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 0], y_train_predict[:, 0]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 0], y_train_predict[:, 0]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 0], y_train_predict[:, 0]))

# Đánh giá cho 'open'
print('\nĐánh giá cho giá mở cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 1], y_train_predict[:, 1]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 1], y_train_predict[:, 1]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 1], y_train_predict[:, 1]))


# Đánh giá cho 'high'
print('\nĐánh giá cho giá cao nhất trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 2], y_train_predict[:, 2]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 2], y_train_predict[:, 2]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 2], y_train_predict[:, 2]))

# Đánh giá cho 'low'
print('\nĐánh giá cho giá thấp nhất trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 3], y_train_predict[:, 3]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 3], y_train_predict[:, 3]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 3], y_train_predict[:, 3]))
# Out:
# Đánh giá cho giá đóng cửa trên tập train:
# R^2 (Độ phù hợp): 0.9922924510506178
# MAE (Sai số tuyệt đối trung bình): 897.5913887392242
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.019401941926225342
#
# Đánh giá cho giá mở cửa trên tập train:
# R^2 (Độ phù hợp): 0.995757269680128
# MAE (Sai số tuyệt đối trung bình): 637.6742780172414
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.01364917672959738
#
# Đánh giá cho giá cao nhất trên tập train:
# R^2 (Độ phù hợp): 0.995622939743222
# MAE (Sai số tuyệt đối trung bình): 743.5750808189655
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.016085371289436108
#
# Đánh giá cho giá thấp nhất trên tập train:
# R^2 (Độ phù hợp): 0.9941925357895793
# MAE (Sai số tuyệt đối trung bình): 708.5060843211212
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.015626679612823564

# %%
train_data1
# Out:
#             close   open   high    low  Dự đoán Close  Dự đoán Open  \
# time
# 2013-03-20  26140  25220  26390  24870   24169.404297  24178.687500
# 2013-03-21  25370  26140  26140  25320   25332.884766  25342.173828
# 2013-03-22  25620  25370  26640  25320   25593.535156  25602.517578
# 2013-03-25  25370  26140  26390  25320   25600.839844  25609.785156
# 2013-03-26  25320  25370  25880  25320   25487.375000  25496.388672
# ...           ...    ...    ...    ...            ...           ...
# 2019-01-03  58720  59980  60320  58240   61051.789062  61083.351562
# 2019-01-04  58590  58110  59280  57130   60157.058594  60188.144531
# 2019-01-07  59830  59980  60520  59280   59487.628906  59518.000000
# 2019-01-08  61220  59830  61500  59830   60941.777344  60971.539062
# 2019-01-09  62340  62190  62680  61710   61659.359375  61689.312500
#
#             Dự đoán High   Dự đoán Low
# time
# 2013-03-20  24508.779297  23957.505859
# 2013-03-21  25686.361328  25101.464844
# 2013-03-22  25949.640625  25359.185547
# 2013-03-25  25956.380859  25367.298828
# 2013-03-26  25840.808594  25256.005859
# ...                  ...           ...
# 2019-01-03  61824.214844  60133.058594
# 2019-01-04  60916.660156  59256.433594
# 2019-01-07  60237.261719  58600.089844
# 2019-01-08  61711.566406  60026.636719
# 2019-01-09  62440.156250  60732.054688
#
# [1450 rows x 8 columns]

# %%
# Đánh giá cho 'close'
print('Đánh giá cho giá đóng cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 0], y_train_predict[:, 0]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 0], y_train_predict[:, 0]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 0], y_train_predict[:, 0]))

# Đánh giá cho 'open'
print('\nĐánh giá cho giá mở cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 1], y_train_predict[:, 1]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 1], y_train_predict[:, 1]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 1], y_train_predict[:, 1]))


# Đánh giá cho 'high'
print('\nĐánh giá cho giá cao nhất trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 2], y_train_predict[:, 2]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 2], y_train_predict[:, 2]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 2], y_train_predict[:, 2]))

# Đánh giá cho 'low'
print('\nĐánh giá cho giá thấp nhất trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 3], y_train_predict[:, 3]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 3], y_train_predict[:, 3]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 3], y_train_predict[:, 3]))
# Out:
# Đánh giá cho giá đóng cửa trên tập train:
# R^2 (Độ phù hợp): 0.9922924510506178
# MAE (Sai số tuyệt đối trung bình): 897.5913887392242
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.019401941926225342
#
# Đánh giá cho giá mở cửa trên tập train:
# R^2 (Độ phù hợp): 0.995757269680128
# MAE (Sai số tuyệt đối trung bình): 637.6742780172414
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.01364917672959738
#
# Đánh giá cho giá cao nhất trên tập train:
# R^2 (Độ phù hợp): 0.995622939743222
# MAE (Sai số tuyệt đối trung bình): 743.5750808189655
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.016085371289436108
#
# Đánh giá cho giá thấp nhất trên tập train:
# R^2 (Độ phù hợp): 0.9941925357895793
# MAE (Sai số tuyệt đối trung bình): 708.5060843211212
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.015626679612823564

# %%
test_data1
# Out:
#             close   open   high    low  Dự đoán Close  Dự đoán Open  \
# time
# 2019-01-10  63300  63030  63930  62750   63003.156250  63033.375000
# 2019-01-11  63090  63370  63580  62470   63956.582031  63987.566406
# 2019-01-14  62060  62960  62960  61710   63763.378906  63795.328125
# 2019-01-15  62610  62060  62750  62060   63129.562500  63162.117188
# 2019-01-16  62820  63370  63370  62610   63506.015625  63538.820312
# ...           ...    ...    ...    ...            ...           ...
# 2024-03-19  79700  81000  81000  79700   81188.046875  81251.328125
# 2024-03-20  81000  80000  81200  79600   81112.171875  81175.085938
# 2024-03-21  81000  81900  81900  80500   81788.414062  81851.234375
# 2024-03-22  80500  81000  81500  80400   82014.664062  82078.078125
# 2024-03-25  80400  80500  81400  80100   81521.687500  81585.726562
#
#             Dự đoán High   Dự đoán Low
# time
# 2019-01-10  63804.410156  62051.589844
# 2019-01-11  64773.488281  62988.503906
# 2019-01-14  64579.574219  62800.589844
# 2019-01-15  63937.953125  62179.523438
# 2019-01-16  64320.257812  62548.425781
# ...                  ...           ...
# 2024-03-19  82313.820312  79869.851562
# 2024-03-20  82236.921875  79794.781250
# 2024-03-21  82923.765625  80456.937500
# 2024-03-22  83154.343750  80678.585938
# 2024-03-25  82654.492188  80195.460938
#
# [1300 rows x 8 columns]

# %% [markdown]
# # Dự đoán giá tương lai và so sánh với giá ngày cuối

# %%
# Lấy ngày kế tiếp sau ngày cuối cùng trong tập dữ liệu để dự đoán
next_date = df['time'].iloc[-1] + pd.Timedelta(days=1)

# Sử dụng mô hình để dự đoán

# Điều chỉnh đoạn code để lấy 50 điểm dữ liệu gần nhất từ cả 'close' và 'open' cho dự đoán
x_next = np.array([sc_train[-50:, :]])  # Lấy 50 bản ghi gần nhất cho cả 'close' và 'open'
x_next = np.reshape(x_next, (x_next.shape[0], x_next.shape[1], 4))  # Reshape để phù hợp với mô hình

y_next_predict = final_model.predict(x_next)
y_next_predict = sc.inverse_transform(y_next_predict)  # Chuyển về giá trị ban đầu

# Thêm dữ liệu dự đoán của ngày kế tiếp vào DataFrame
df_next = pd.DataFrame({'time': [next_date],
                        'close': [y_next_predict[0][0]],
                        'open': [y_next_predict[0][1]],
                        'high': [y_next_predict[0][2]],
                        'low': [y_next_predict[0][3]]})
df1 = pd.concat([df1, df_next.set_index('time')])


# Vẽ biểu đồ mới với dự đoán cho ngày kế tiếp
plt.figure(figsize=(15, 5))
plt.plot(df1.index, df1['close'], label='Giá đóng cửa thực tế', color='red')
plt.plot(df1.index, df1['open'], label='Giá mở cửa thực tế', color='blue')
plt.scatter(df_next['time'], df_next['close'], color='orange', label='Dự đoán giá đóng cửa ngày kế tiếp', zorder=5)
plt.scatter(df_next['time'], df_next['open'], color='purple', label='Dự đoán giá mở cửa ngày kế tiếp', zorder=5)
plt.scatter(df_next['time'], df_next['high'], color='green', label='Dự đoán giá cao nhất ngày kế tiếp', zorder=5)
plt.scatter(df_next['time'], df_next['low'], color='brown', label='Dự đoán giá thấp nhất ngày kế tiếp', zorder=5)

plt.xlabel('Thời gian')
plt.ylabel('Giá (VNĐ)')
plt.title('So sánh giá dự báo và giá thực tế')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
# Lấy giá trị đóng cửa và mở cửa của ngày cuối cùng trong tập dữ liệu
actual_closing_price = df['close'].iloc[-1]
actual_opening_price = df['open'].iloc[-1]

actual_high_price = df['high'].iloc[-1]
actual_low_price = df['low'].iloc[-1]

# Sử dụng mô hình để dự đoán giá cho ngày kế tiếp (đã thực hiện ở bước trước)

# Tạo DataFrame so sánh giá dự đoán với giá thực tế của ngày cuối cùng trong tập dữ liệu
comparison_df = pd.DataFrame({
    'time': [next_date],
    'Giá đóng cửa dự đoán': [y_next_predict[0][0]],
    'Giá mở cửa dự đoán': [y_next_predict[0][1]],
    'Giá cao nhất dự đoán': [y_next_predict[0][2]],  # Giả sử cột thứ ba là dự đoán giá cao nhất
    'Giá thấp nhất dự đoán': [y_next_predict[0][3]],  # Giả sử cột thứ tư là dự đoán giá thấp nhất
    'Giá đóng cửa thực tế ngày trước': [actual_closing_price],
    'Giá mở cửa thực tế ngày trước': [actual_opening_price],
    'Giá cao nhất thực tế ngày trước': [actual_high_price],
    'Giá thấp nhất thực tế ngày trước': [actual_low_price]
})

# In ra bảng so sánh
comparison_df
# Out:
#         time  Giá đóng cửa dự đoán  Giá mở cửa dự đoán  Giá cao nhất dự đoán  \
# 0 2024-03-26          81679.109375         81742.96875          82814.289062
#
#    Giá thấp nhất dự đoán  Giá đóng cửa thực tế ngày trước  \
# 0           80349.210938                            80400
#
#    Giá mở cửa thực tế ngày trước  Giá cao nhất thực tế ngày trước  \
# 0                          80500                            81400
#
#    Giá thấp nhất thực tế ngày trước
# 0                             80100
