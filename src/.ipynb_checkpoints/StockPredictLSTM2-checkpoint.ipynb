# %% [markdown]
#  # Bước 1: Import thư viện

# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trung bình

# %% [markdown]
# # Bước 2: Đọc dữ liệu

# %%
df = pd.read_excel('../Assest/data/dulieu.xlsx')

# %%
#dữ liệu 5 dòng đầu
df.head()
# Out:
#    Unnamed: 0       time   open   high    low  close   volume          MA50  \
# 0           0 2013-01-02  19640  19790  19590  19790    90770  19790.000000
# 1           1 2013-01-03  19790  20040  19690  19790  1618510  19790.000000
# 2           2 2013-01-04  20150  20400  19790  20250  1318980  19943.333333
# 3           3 2013-01-07  20400  20450  20250  20250   701600  20020.000000
# 4           4 2013-01-08  20190  21010  20100  20700   871680  20156.000000
#
#           MA200  sup  Buy_signal  Sell_signal
# 0  19790.000000  0.0           0            0
# 1  19790.000000  NaN           0            0
# 2  19943.333333  NaN           0            0
# 3  20020.000000  NaN           0            0
# 4  20156.000000  NaN           0            0

# %% [markdown]
# # Bước 3: Mô tả dữ liệu

# %%
#định dạng cấu trúc thời gian
df["time"] = pd.to_datetime(df.time, format="%Y-%m-%d")

#df = df.drop(columns=['Unnamed: 0'])
#kích thước dữ liệu
df.shape

#xác định kiểu dữ liệu
df.info()

#mô tả bộ dữ liệu
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2800 non-null   int64
#  1   time         2800 non-null   datetime64[ns]
#  2   open         2800 non-null   int64
#  3   high         2800 non-null   int64
#  4   low          2800 non-null   int64
#  5   close        2800 non-null   int64
#  6   volume       2800 non-null   int64
#  7   MA50         2800 non-null   float64
#  8   MA200        2800 non-null   float64
#  9   sup          2794 non-null   float64
#  10  Buy_signal   2800 non-null   int64
#  11  Sell_signal  2800 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 262.6 KB
#         Unnamed: 0                 time           open           high  \
# count  2800.000000                 2800    2800.000000    2800.000000
# mean   1399.500000  2018-08-17 15:54:00   57771.999286   58543.263571
# min       0.000000  2013-01-02 00:00:00   17380.000000   17720.000000
# 25%     699.750000  2015-10-29 18:00:00   37770.000000   38310.000000
# 50%    1399.500000  2018-08-18 12:00:00   59820.000000   60700.000000
# 75%    2099.250000  2021-06-08 06:00:00   75685.000000   76402.500000
# max    2799.000000  2024-03-25 00:00:00  102560.000000  104910.000000
# std     808.434702                  NaN   20811.229597   21125.291534
#
#                  low          close        volume         MA50         MA200  \
# count    2800.000000    2800.000000  2.800000e+03   2800.00000   2800.000000
# mean    57001.083571   57716.315714  6.153748e+05  57213.62448  55744.291734
# min     17210.000000   17320.000000  3.086000e+04  19790.00000  19790.000000
# 25%     37400.000000   37770.000000  2.963550e+05  37667.58500  37717.075000
# 50%     58730.000000   59820.000000  5.044500e+05  59823.02000  56097.460000
# 75%     74882.500000   75520.000000  7.908750e+05  75226.00000  71702.202500
# max    100440.000000  104910.000000  4.515800e+06  89808.20000  88514.550000
# std     20486.579832   20781.400694  4.637070e+05  20613.79648  20078.883386
#
#                  sup   Buy_signal  Sell_signal
# count    2794.000000  2800.000000  2800.000000
# mean    57861.749067     0.012857     0.012857
# min         0.000000     0.000000     0.000000
# 25%     38247.325359     0.000000     0.000000
# 50%     60606.965419     0.000000     0.000000
# 75%     76397.042571     0.000000     0.000000
# max    109698.097222     1.000000     1.000000
# std     21260.338648     0.112678     0.112678

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2800 non-null   int64
#  1   time         2800 non-null   datetime64[ns]
#  2   open         2800 non-null   int64
#  3   high         2800 non-null   int64
#  4   low          2800 non-null   int64
#  5   close        2800 non-null   int64
#  6   volume       2800 non-null   int64
#  7   MA50         2800 non-null   float64
#  8   MA200        2800 non-null   float64
#  9   sup          2794 non-null   float64
#  10  Buy_signal   2800 non-null   int64
#  11  Sell_signal  2800 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 262.6 KB

# %% [markdown]
# # Bước 4: Tiền xử lý dữ liệu

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Sắp xếp lại dữ liệu theo thứ tự thời gian
df = df.sort_values(by='time')

# Lấy thông tin năm từ cột 'time'
df['year'] = df['time'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['time'], df['close'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
df1 = pd.DataFrame(df,columns=['time','close', 'open'])
df1.index = df1.time
df1.drop('time',axis=1,inplace=True)
df1
# Out:
#             close   open
# time
# 2013-01-02  19790  19640
# 2013-01-03  19790  19790
# 2013-01-04  20250  20150
# 2013-01-07  20250  20400
# 2013-01-08  20700  20190
# ...           ...    ...
# 2024-03-19  79700  81000
# 2024-03-20  81000  80000
# 2024-03-21  81000  81900
# 2024-03-22  80500  81000
# 2024-03-25  80400  80500
#
# [2800 rows x 2 columns]

# %%
#chia tập dữ liệu
data = df1.values
train_data = data[:1500]
test_data = data[1500:]

# %%
data
# Out:
# array([[19790, 19640],
#        [19790, 19790],
#        [20250, 20150],
#        ...,
#        [81000, 81900],
#        [80500, 81000],
#        [80400, 80500]], dtype=int64)

# %%
#chuẩn hóa dữ liệu

sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)  # Chỉ sử dụng train_data để fit scaler

# %%
#tạo vòng lặp các giá trị
x_train, y_train = [], []
for i in range(50, len(train_data)):
    x_train.append(sc_train[i-50:i, 0:2])  # Lấy 50 giá trị liên tiếp, bao gồm cả close và open
    y_train.append(sc_train[i, 0:2])  # Lấy ra giá close và open ngày hôm sau

# %%
# x_train
# y_train

# %%
#xếp dữ liệu thành 1 mảng 2 chiều
x_train = np.array(x_train)
y_train = np.array(y_train)

#xếp lại dữ liệu thành mảng 1 chiều
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],2))
y_train = np.reshape(y_train,(y_train.shape[0],2))

# %% [markdown]
# # Bước 5: Xây dựng và huấn luyện mô hình

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(x_train.shape[1],2),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(2)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa adam
model.compile(loss='mean_absolute_error',optimizer='adam')

# %%
#huấn luyện mô hình
save_model = "../model/models.keras"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')
model.fit(x_train,y_train,epochs=100,batch_size=50,verbose=2,callbacks=[best_model])
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.09483, saving model to ../model/models.keras
# 29/29 - 2s - 70ms/step - loss: 0.0948
# Epoch 2/100
#
# Epoch 2: loss improved from 0.09483 to 0.05410, saving model to ../model/models.keras
# 29/29 - 1s - 26ms/step - loss: 0.0541
# Epoch 3/100
#
# Epoch 3: loss improved from 0.05410 to 0.04788, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0479
# Epoch 4/100
#
# Epoch 4: loss improved from 0.04788 to 0.04778, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0478
# Epoch 5/100
#
# Epoch 5: loss improved from 0.04778 to 0.04485, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0448
# Epoch 6/100
#
# Epoch 6: loss improved from 0.04485 to 0.04232, saving model to ../model/models.keras
# 29/29 - 1s - 23ms/step - loss: 0.0423
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.04232
# 29/29 - 1s - 23ms/step - loss: 0.0424
# Epoch 8/100
#
# Epoch 8: loss improved from 0.04232 to 0.04048, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0405
# Epoch 9/100
#
# Epoch 9: loss improved from 0.04048 to 0.03643, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0364
# Epoch 10/100
#
# Epoch 10: loss improved from 0.03643 to 0.03554, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0355
# Epoch 11/100
#
# Epoch 11: loss improved from 0.03554 to 0.03472, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0347
# Epoch 12/100
#
# Epoch 12: loss improved from 0.03472 to 0.03301, saving model to ../model/models.keras
# 29/29 - 1s - 27ms/step - loss: 0.0330
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03301 to 0.03261, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0326
# Epoch 14/100
#
# Epoch 14: loss improved from 0.03261 to 0.03136, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0314
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03136 to 0.03079, saving model to ../model/models.keras
# 29/29 - 1s - 25ms/step - loss: 0.0308
# Epoch 16/100
#
# Epoch 16: loss improved from 0.03079 to 0.02913, saving model to ../model/models.keras
# 29/29 - 1s - 28ms/step - loss: 0.0291
# Epoch 17/100
#
# Epoch 17: loss improved from 0.02913 to 0.02840, saving model to ../model/models.keras
# 29/29 - 1s - 26ms/step - loss: 0.0284
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.02840
# 29/29 - 1s - 26ms/step - loss: 0.0298
# Epoch 19/100
#
# Epoch 19: loss improved from 0.02840 to 0.02750, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0275
# Epoch 20/100
#
# Epoch 20: loss improved from 0.02750 to 0.02670, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0267
# Epoch 21/100
#
# Epoch 21: loss improved from 0.02670 to 0.02594, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0259
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.02594
# 29/29 - 1s - 23ms/step - loss: 0.0267
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.02594
# 29/29 - 1s - 23ms/step - loss: 0.0261
# Epoch 24/100
#
# Epoch 24: loss improved from 0.02594 to 0.02555, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0255
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02555 to 0.02457, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0246
# Epoch 26/100
#
# Epoch 26: loss improved from 0.02457 to 0.02307, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0231
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.02307
# 29/29 - 1s - 23ms/step - loss: 0.0240
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.02307
# 29/29 - 1s - 23ms/step - loss: 0.0232
# Epoch 29/100
#
# Epoch 29: loss improved from 0.02307 to 0.02305, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0230
# Epoch 30/100
#
# Epoch 30: loss improved from 0.02305 to 0.02271, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0227
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.02271
# 29/29 - 1s - 24ms/step - loss: 0.0230
# Epoch 32/100
#
# Epoch 32: loss improved from 0.02271 to 0.02256, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0226
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.02256
# 29/29 - 1s - 23ms/step - loss: 0.0227
# Epoch 34/100
#
# Epoch 34: loss improved from 0.02256 to 0.02094, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0209
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.02094
# 29/29 - 1s - 24ms/step - loss: 0.0230
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.02094
# 29/29 - 1s - 27ms/step - loss: 0.0210
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.02094
# 29/29 - 1s - 26ms/step - loss: 0.0222
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.02094
# 29/29 - 1s - 29ms/step - loss: 0.0211
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.02094
# 29/29 - 1s - 27ms/step - loss: 0.0218
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.02094
# 29/29 - 1s - 27ms/step - loss: 0.0228
# Epoch 41/100
#
# Epoch 41: loss improved from 0.02094 to 0.02051, saving model to ../model/models.keras
# 29/29 - 1s - 27ms/step - loss: 0.0205
# Epoch 42/100
#
# Epoch 42: loss improved from 0.02051 to 0.02024, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0202
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.02024
# 29/29 - 1s - 24ms/step - loss: 0.0205
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.02024
# 29/29 - 1s - 25ms/step - loss: 0.0204
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.02024
# 29/29 - 1s - 25ms/step - loss: 0.0203
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02024
# 29/29 - 1s - 24ms/step - loss: 0.0204
# Epoch 47/100
#
# Epoch 47: loss improved from 0.02024 to 0.01963, saving model to ../model/models.keras
# 29/29 - 1s - 26ms/step - loss: 0.0196
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01963
# 29/29 - 1s - 25ms/step - loss: 0.0201
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01963
# 29/29 - 1s - 23ms/step - loss: 0.0204
# Epoch 50/100
#
# Epoch 50: loss improved from 0.01963 to 0.01961, saving model to ../model/models.keras
# 29/29 - 1s - 26ms/step - loss: 0.0196
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01961
# 29/29 - 1s - 23ms/step - loss: 0.0202
# Epoch 52/100
#
# Epoch 52: loss improved from 0.01961 to 0.01943, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0194
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01943
# 29/29 - 1s - 23ms/step - loss: 0.0199
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01943
# 29/29 - 1s - 23ms/step - loss: 0.0195
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01943
# 29/29 - 1s - 23ms/step - loss: 0.0198
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01943
# 29/29 - 1s - 23ms/step - loss: 0.0194
# Epoch 57/100
#
# Epoch 57: loss improved from 0.01943 to 0.01858, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0186
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01858
# 29/29 - 1s - 24ms/step - loss: 0.0195
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01858
# 29/29 - 1s - 23ms/step - loss: 0.0187
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01858
# 29/29 - 1s - 25ms/step - loss: 0.0190
# Epoch 61/100
#
# Epoch 61: loss improved from 0.01858 to 0.01826, saving model to ../model/models.keras
# 29/29 - 1s - 28ms/step - loss: 0.0183
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01826
# 29/29 - 1s - 25ms/step - loss: 0.0189
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01826
# 29/29 - 1s - 26ms/step - loss: 0.0187
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01826
# 29/29 - 1s - 23ms/step - loss: 0.0188
# Epoch 65/100
#
# Epoch 65: loss improved from 0.01826 to 0.01763, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0176
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0183
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0196
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0178
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0188
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0185
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0180
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01763
# 29/29 - 1s - 23ms/step - loss: 0.0187
# Epoch 73/100
#
# Epoch 73: loss improved from 0.01763 to 0.01717, saving model to ../model/models.keras
# 29/29 - 1s - 24ms/step - loss: 0.0172
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0181
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0173
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0175
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0189
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0184
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0174
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0183
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0187
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0182
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0192
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01717
# 29/29 - 1s - 27ms/step - loss: 0.0186
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01717
# 29/29 - 1s - 26ms/step - loss: 0.0187
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01717
# 29/29 - 1s - 27ms/step - loss: 0.0183
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01717
# 29/29 - 1s - 25ms/step - loss: 0.0181
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0193
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0179
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0177
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0178
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0178
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0176
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0180
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0179
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0183
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01717
# 29/29 - 1s - 24ms/step - loss: 0.0174
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0172
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0179
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01717
# 29/29 - 1s - 23ms/step - loss: 0.0173

# %%
#dữ liệu train
y_train = sc.inverse_transform(y_train) #giá thực
final_model = load_model("../model/models.keras")
y_train_predict = final_model.predict(x_train) #dự đoán giá đóng cửa trên tập đã train
y_train_predict = sc.inverse_transform(y_train_predict) #giá dự đoán
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %% [markdown]
# # Bước 6: Tái sử dụng mô hình

# %%
# Giả sử df1 là DataFrame chứa cả 'close' và 'open' mà bạn đã fit MinMaxScaler
# Đúng cách để biến đổi dữ liệu test là sử dụng cả hai cột như sau:

# Không cần reshape test data như bạn đã làm
# test = test.reshape(-1,1)  # Bỏ dòng này

# Xử lý dữ liệu test
test = df1[len(train_data)-50:].values  # Lấy dữ liệu test với cả hai cột

# Sử dụng MinMaxScaler đã được fit với cả hai cột để biến đổi
sc_test = sc.transform(test)

x_test, y_test = [], []
for i in range(50, test.shape[0]):
    x_test.append(sc_test[i-50:i])
x_test = np.array(x_test)

# Đối với mô hình LSTM, dữ liệu đầu vào cần được reshape thành [samples, time steps, features]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 2))

# Sau đó, bạn có thể sử dụng mô hình để dự đoán
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)  # Chuyển dữ liệu dự đoán về dạng ban đầu
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# # Độ chính xác của mô hình

# %%
# Chuẩn bị dữ liệu cho việc vẽ biểu đồ
train_data1 = df1.iloc[50:1500].copy()  # Sử dụng .copy() để tránh cảnh báo SettingWithCopy
test_data1 = df1.iloc[1500:].copy()

# Cập nhật DataFrame với dữ liệu dự đoán
train_data1['Dự đoán Close'] = y_train_predict[:, 0]  # Cột đầu tiên cho 'close'
train_data1['Dự đoán Open'] = y_train_predict[:, 1]  # Cột thứ hai cho 'open'

test_data1['Dự đoán Close'] = y_test_predict[:, 0]  # Tương tự cho dữ liệu kiểm tra
test_data1['Dự đoán Open'] = y_test_predict[:, 1]

plt.figure(figsize=(24,8))

# Vẽ giá 'close' và 'open' thực tế
plt.plot(df1.index, df1['close'], label='Giá đóng cửa thực tế', color='red', alpha=0.5)
plt.plot(df1.index, df1['open'], label='Giá mở cửa thực tế', color='blue', alpha=0.5)

# Vẽ giá dự đoán 'close' và 'open' cho dữ liệu huấn luyện và kiểm tra
plt.plot(train_data1.index, train_data1['Dự đoán Close'], label='Giá đóng cửa dự đoán train', color='red', linestyle='--')
plt.plot(train_data1.index, train_data1['Dự đoán Open'], label='Giá mở cửa dự đoán train', color='blue', linestyle='--')

plt.plot(test_data1.index, test_data1['Dự đoán Close'], label='Giá đóng cửa dự đoán test', color='red', linestyle='-.')
plt.plot(test_data1.index, test_data1['Dự đoán Open'], label='Giá mở cửa dự đoán test', color='blue', linestyle='-.')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá (VNĐ)')
plt.legend()
plt.show()

# %%
# Đánh giá cho 'close'
print('Đánh giá cho giá đóng cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 0], y_train_predict[:, 0]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 0], y_train_predict[:, 0]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 0], y_train_predict[:, 0]))

# Đánh giá cho 'open'
print('\nĐánh giá cho giá mở cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 1], y_train_predict[:, 1]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 1], y_train_predict[:, 1]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 1], y_train_predict[:, 1]))
# Out:
# Đánh giá cho giá đóng cửa trên tập train:
# R^2 (Độ phù hợp): 0.9926607816726819
# MAE (Sai số tuyệt đối trung bình): 896.0883028017241
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.01979012869100852
#
# Đánh giá cho giá mở cửa trên tập train:
# R^2 (Độ phù hợp): 0.9960333693788935
# MAE (Sai số tuyệt đối trung bình): 645.7375794719827
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.014003193158133259

# %%
train_data1
# Out:
#             close   open  Dự đoán Close  Dự đoán Open
# time
# 2013-03-20  26140  25220   24615.343750  24581.511719
# 2013-03-21  25370  26140   25703.554688  25669.478516
# 2013-03-22  25620  25370   26028.095703  25995.916016
# 2013-03-25  25370  26140   25996.679688  25964.314453
# 2013-03-26  25320  25370   25902.347656  25868.070312
# ...           ...    ...            ...           ...
# 2019-01-03  58720  59980   59934.304688  59815.593750
# 2019-01-04  58590  58110   58969.234375  58857.296875
# 2019-01-07  59830  59980   58241.890625  58130.855469
# 2019-01-08  61220  59830   59187.957031  59071.035156
# 2019-01-09  62340  62190   60387.292969  60269.906250
#
# [1450 rows x 4 columns]

# %%
# Đánh giá cho 'close'
print('Đánh giá cho giá đóng cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 0], y_train_predict[:, 0]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 0], y_train_predict[:, 0]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 0], y_train_predict[:, 0]))

# Đánh giá cho 'open'
print('\nĐánh giá cho giá mở cửa trên tập train:')
print('R^2 (Độ phù hợp):', r2_score(y_train[:, 1], y_train_predict[:, 1]))
print('MAE (Sai số tuyệt đối trung bình):', mean_absolute_error(y_train[:, 1], y_train_predict[:, 1]))
print('MAPE (Phần trăm sai số tuyệt đối trung bình):', mean_absolute_percentage_error(y_train[:, 1], y_train_predict[:, 1]))
# Out:
# Đánh giá cho giá đóng cửa trên tập train:
# R^2 (Độ phù hợp): 0.9926607816726819
# MAE (Sai số tuyệt đối trung bình): 896.0883028017241
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.01979012869100852
#
# Đánh giá cho giá mở cửa trên tập train:
# R^2 (Độ phù hợp): 0.9960333693788935
# MAE (Sai số tuyệt đối trung bình): 645.7375794719827
# MAPE (Phần trăm sai số tuyệt đối trung bình): 0.014003193158133259

# %%
test_data1
# Out:
#             close   open  Dự đoán Close  Dự đoán Open
# time
# 2019-01-10  63300  63030   61688.273438  61571.847656
# 2019-01-11  63090  63370   62597.933594  62484.121094
# 2019-01-14  62060  62960   62586.203125  62475.835938
# 2019-01-15  62610  62060   61751.742188  61642.937500
# 2019-01-16  62820  63370   61723.628906  61609.675781
# ...           ...    ...            ...           ...
# 2024-03-19  79700  81000   79521.546875  79403.843750
# 2024-03-20  81000  80000   78520.796875  78402.890625
# 2024-03-21  81000  81900   79310.695312  79184.375000
# 2024-03-22  80500  81000   79971.578125  79843.507812
# 2024-03-25  80400  80500   79443.390625  79320.843750
#
# [1300 rows x 4 columns]

# %% [markdown]
# # Dự đoán giá tương lai và so sánh với giá ngày cuối

# %%
# Lấy ngày kế tiếp sau ngày cuối cùng trong tập dữ liệu để dự đoán
next_date = df['time'].iloc[-1] + pd.Timedelta(days=1)

# Sử dụng mô hình để dự đoán

# Điều chỉnh đoạn code để lấy 50 điểm dữ liệu gần nhất từ cả 'close' và 'open' cho dự đoán
x_next = np.array([sc_train[-50:, :]])  # Lấy 50 bản ghi gần nhất cho cả 'close' và 'open'
x_next = np.reshape(x_next, (x_next.shape[0], x_next.shape[1], 2))  # Reshape để phù hợp với mô hình

y_next_predict = final_model.predict(x_next)
y_next_predict = sc.inverse_transform(y_next_predict)  # Chuyển về giá trị ban đầu

# Thêm dữ liệu dự đoán của ngày kế tiếp vào DataFrame
df_next = pd.DataFrame({'time': [next_date], 'close': [y_next_predict[0][0]], 'open': [y_next_predict[0][1]]})
df1 = pd.concat([df1, df_next.set_index('time')])

# Vẽ biểu đồ mới với dự đoán cho ngày kế tiếp
plt.figure(figsize=(15, 5))
plt.plot(df1.index, df1['close'], label='Giá đóng cửa thực tế', color='red')
plt.scatter(df_next['time'], df_next['close'], color='orange', label='Dự đoán giá đóng cửa ngày kế tiếp', zorder=5)
plt.scatter(df_next['time'], df_next['open'], color='purple', label='Dự đoán giá mở cửa ngày kế tiếp', zorder=5)

plt.xlabel('Thời gian')
plt.ylabel('Giá (VNĐ)')
plt.title('So sánh giá dự báo và giá thực tế')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# Lấy giá trị đóng cửa và mở cửa của ngày cuối cùng trong tập dữ liệu
actual_closing_price = df['close'].iloc[-1]
actual_opening_price = df['open'].iloc[-1]

# Sử dụng mô hình để dự đoán giá cho ngày kế tiếp (đã thực hiện ở bước trước)
# y_next_predict = final_model.predict(x_next)
# y_next_predict = sc.inverse_transform(y_next_predict)  # Giả sử dữ liệu đã được chuyển về dạng ban đầu

# Tạo DataFrame so sánh giá dự đoán với giá thực tế của ngày cuối cùng trong tập dữ liệu
comparison_df = pd.DataFrame({
    'time': [next_date],
    'Giá đóng cửa dự đoán': [y_next_predict[0][0]],  # Giả sử cột đầu tiên là dự đoán giá đóng cửa
    'Giá mở cửa dự đoán': [y_next_predict[0][1]],    # Giả sử cột thứ hai là dự đoán giá mở cửa
    'Giá đóng cửa thực tế ngày trước': [actual_closing_price],
    'Giá mở cửa thực tế ngày trước': [actual_opening_price]
})

# In ra bảng so sánh
comparison_df
# Out:
#         time  Giá đóng cửa dự đoán  Giá mở cửa dự đoán  \
# 0 2024-03-26            79143.6875        79021.476562
#
#    Giá đóng cửa thực tế ngày trước  Giá mở cửa thực tế ngày trước
# 0                            80400                          80500
