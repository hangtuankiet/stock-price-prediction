# %% [markdown]
#  # Bước 1: Import thư viện

# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trung bình

# %% [markdown]
# # Bước 2: Đọc dữ liệu

# %%
df = pd.read_csv('./dulieu.csv')

# %%
#dữ liệu 5 dòng đầu
df.head()
# Out:
#         time   open   high    low  close   volume         MA50        MA200  \
# 0 2013-01-02  19640  19790  19590  19790    90770  19790.00000  19790.00000
# 1 2013-01-03  19790  20040  19690  19790  1618510  19790.00000  19790.00000
# 2 2013-01-04  20150  20400  19790  20250  1318980  19943.33333  19943.33333
# 3 2013-01-07  20400  20450  20250  20250   701600  20020.00000  20020.00000
# 4 2013-01-08  20190  21010  20100  20700   871680  20156.00000  20156.00000
#
#    sup  Buy_signal  Sell_signal
# 0  0.0           0            0
# 1  NaN           0            0
# 2  NaN           0            0
# 3  NaN           0            0
# 4  NaN           0            0

# %% [markdown]
# # Bước 3: Mô tả dữ liệu

# %%
#định dạng cấu trúc thời gian
df["time"] = pd.to_datetime(df.time, format="%Y-%m-%d")

#df = df.drop(columns=['Unnamed: 0'])
#kích thước dữ liệu
df.shape

#xác định kiểu dữ liệu
df.info()

#mô tả bộ dữ liệu
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         2800 non-null   datetime64[ns]
#  1   open         2800 non-null   int64
#  2   high         2800 non-null   int64
#  3   low          2800 non-null   int64
#  4   close        2800 non-null   int64
#  5   volume       2800 non-null   int64
#  6   MA50         2800 non-null   float64
#  7   MA200        2800 non-null   float64
#  8   sup          2794 non-null   float64
#  9   Buy_signal   2800 non-null   int64
#  10  Sell_signal  2800 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(7)
# memory usage: 240.8 KB
#                       time           open           high            low  \
# count                 2800    2800.000000    2800.000000    2800.000000
# mean   2018-08-17 15:54:00   57771.999286   58543.263571   57001.083571
# min    2013-01-02 00:00:00   17380.000000   17720.000000   17210.000000
# 25%    2015-10-29 18:00:00   37770.000000   38310.000000   37400.000000
# 50%    2018-08-18 12:00:00   59820.000000   60700.000000   58730.000000
# 75%    2021-06-08 06:00:00   75685.000000   76402.500000   74882.500000
# max    2024-03-25 00:00:00  102560.000000  104910.000000  100440.000000
# std                    NaN   20811.229597   21125.291534   20486.579832
#
#                close        volume         MA50         MA200            sup  \
# count    2800.000000  2.800000e+03   2800.00000   2800.000000    2794.000000
# mean    57716.315714  6.153748e+05  57213.62448  55744.291734   57861.749067
# min     17320.000000  3.086000e+04  19790.00000  19790.000000       0.000000
# 25%     37770.000000  2.963550e+05  37667.58500  37717.075000   38247.325360
# 50%     59820.000000  5.044500e+05  59823.02000  56097.460000   60606.965420
# 75%     75520.000000  7.908750e+05  75226.00000  71702.202500   76397.042570
# max    104910.000000  4.515800e+06  89808.20000  88514.550000  109698.097200
# std     20781.400694  4.637070e+05  20613.79648  20078.883386   21260.338647
#
#         Buy_signal  Sell_signal
# count  2800.000000  2800.000000
# mean      0.012857     0.012857
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max       1.000000     1.000000
# std       0.112678     0.112678

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2800 entries, 0 to 2799
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         2800 non-null   datetime64[ns]
#  1   open         2800 non-null   int64
#  2   high         2800 non-null   int64
#  3   low          2800 non-null   int64
#  4   close        2800 non-null   int64
#  5   volume       2800 non-null   int64
#  6   MA50         2800 non-null   float64
#  7   MA200        2800 non-null   float64
#  8   sup          2794 non-null   float64
#  9   Buy_signal   2800 non-null   int64
#  10  Sell_signal  2800 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(7)
# memory usage: 262.5 KB

# %% [markdown]
# # Bước 4: Tiền xử lý dữ liệu

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Sắp xếp lại dữ liệu theo thứ tự thời gian
df = df.sort_values(by='time')

# Chuyển đổi định dạng cột 'close', 'open', 'high', 'low' từ chuỗi thành số
# df['close'] = df['close'].str.replace(',', '').astype(float)
# df['open'] = df['open'].str.replace(',', '').astype(float)
# df['high'] = df['high'].str.replace(',', '').astype(float)
# df['low'] = df['low'].str.replace(',', '').astype(float)

# Lấy thông tin năm từ cột 'time'
df['year'] = df['time'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['time'], df['close'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
df1 = pd.DataFrame(df,columns=['time','close'])
df1.index = df1.time
df1.drop('time',axis=1,inplace=True)
df1
# Out:
#             close
# time
# 2013-01-02  19790
# 2013-01-03  19790
# 2013-01-04  20250
# 2013-01-07  20250
# 2013-01-08  20700
# ...           ...
# 2024-03-19  79700
# 2024-03-20  81000
# 2024-03-21  81000
# 2024-03-22  80500
# 2024-03-25  80400
#
# [2800 rows x 1 columns]

# %%
#chia tập dữ liệu
data = df1.values
train_data = data[:1500]
test_data = data[1500:]

# %%
data
# Out:
# array([[19790],
#        [19790],
#        [20250],
#        ...,
#        [81000],
#        [80500],
#        [80400]], dtype=int64)

# %%
#chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))
sc_train = sc.fit_transform(data)

# %%
#tạo vòng lặp các giá trị
x_train,y_train=[],[]
for i in range(50,len(train_data)):
  x_train.append(sc_train[i-50:i,0]) #lấy 50 giá đóng cửa liên tục
  y_train.append(sc_train[i,0]) #lấy ra giá đóng cửa ngày hôm sau

#  0.2598470144993721,
#  0.2598470144993721,
#  0.25299691745633063,
#  0.25299691745633063,
#  0.2487726909464551,
#  0.24740267153784679,
#  0.2523119077520265,
#  0.24317844502797126,
#  0.25299691745633063,
#  0.25870533165886517,
#  0.24797351295810027,
#  0.24146592076721085,
#  0.23347414088366253,
#  0.2327891311793584,
#  0.23141911177075009,
#  0.23792670396163945,
#  0.23427331887201736,
#  0.24432012786847812,
#  0.24432012786847812,
#  0.2364425162689805,
#  0.23712752597328463,
#  0.23347414088366253,
#  0.2364425162689805,
#  0.23712752597328463,
#  0.23061993378239526,
#  0.21920310537732618,
#  0.20984130608516954,
#  0.21486471058339995,
#  0.21486471058339995,
#  0.2198881150816303,
#  0.22274232218289758,
#  0.23347414088366253,
#  0.23427331887201736,
#  0.23712752597328463,
#  0.23004909236214183,
#  0.23347414088366253,
#  0.23347414088366253,
#  0.22719488526087456,
#  0.21920310537732618,
#  0.22639570727251968,
#  0.22719488526087456,
#  0.22719488526087456,
#  0.22719488526087456,
#  0.22845073638543212,
#  0.22559652928416485,
#  0.22639570727251968,
#  0.23141911177075009,
#  0.24797351295810027,
#  0.25516611485329377,
#  0.24580431556113713,
#  0.2471743349697454,
#  0.23575750656467637,
#  0.22559652928416485,
#  0.21920310537732618,
#  0.2235415001712524,
#  0.2205731247859345,
#  0.2205731247859345,
#  0.21771891768466722,
#  0.21064048407352437,
#  0.20333371389428018,
#  0.1954561022947825,
#  0.19762529969174564,
#  0.19762529969174564,
#  0.20196369448567186,
#  0.19762529969174564,
#  0.19614111199908668,
#  0.1932869048978194,
#  0.1832400959013586,
#  0.1847242835940176,
#  0.19408608288617424,
#  ...]

# %%
#xếp dữ liệu thành 1 mảng 2 chiều
x_train = np.array(x_train)
y_train = np.array(y_train)

#xếp lại dữ liệu thành mảng 1 chiều
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
y_train = np.reshape(y_train,(y_train.shape[0],1))

# %% [markdown]
# # Bước 5: Xây dựng và huấn luyện mô hình

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(x_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa adam
model.compile(loss='mean_absolute_error',optimizer='adam')
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#huấn luyện mô hình
save_model = "./save_model.keras"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')
model.fit(x_train,y_train,epochs=100,batch_size=50,verbose=2,callbacks=[best_model])
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.08603, saving model to ./save_model.keras
# 29/29 - 2s - 78ms/step - loss: 0.0860
# Epoch 2/100
#
# Epoch 2: loss improved from 0.08603 to 0.04656, saving model to ./save_model.keras
# 29/29 - 1s - 30ms/step - loss: 0.0466
# Epoch 3/100
#
# Epoch 3: loss improved from 0.04656 to 0.03928, saving model to ./save_model.keras
# 29/29 - 1s - 31ms/step - loss: 0.0393
# Epoch 4/100
#
# Epoch 4: loss improved from 0.03928 to 0.03864, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0386
# Epoch 5/100
#
# Epoch 5: loss did not improve from 0.03864
# 29/29 - 1s - 30ms/step - loss: 0.0387
# Epoch 6/100
#
# Epoch 6: loss improved from 0.03864 to 0.03723, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0372
# Epoch 7/100
#
# Epoch 7: loss improved from 0.03723 to 0.03646, saving model to ./save_model.keras
# 29/29 - 1s - 25ms/step - loss: 0.0365
# Epoch 8/100
#
# Epoch 8: loss improved from 0.03646 to 0.03407, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0341
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.03407
# 29/29 - 1s - 29ms/step - loss: 0.0346
# Epoch 10/100
#
# Epoch 10: loss did not improve from 0.03407
# 29/29 - 1s - 33ms/step - loss: 0.0366
# Epoch 11/100
#
# Epoch 11: loss improved from 0.03407 to 0.03253, saving model to ./save_model.keras
# 29/29 - 1s - 27ms/step - loss: 0.0325
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.03253
# 29/29 - 1s - 26ms/step - loss: 0.0329
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03253 to 0.03002, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0300
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.03002
# 29/29 - 1s - 27ms/step - loss: 0.0306
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03002 to 0.02980, saving model to ./save_model.keras
# 29/29 - 1s - 32ms/step - loss: 0.0298
# Epoch 16/100
#
# Epoch 16: loss improved from 0.02980 to 0.02965, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0296
# Epoch 17/100
#
# Epoch 17: loss improved from 0.02965 to 0.02907, saving model to ./save_model.keras
# 29/29 - 1s - 31ms/step - loss: 0.0291
# Epoch 18/100
#
# Epoch 18: loss improved from 0.02907 to 0.02686, saving model to ./save_model.keras
# 29/29 - 1s - 30ms/step - loss: 0.0269
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.02686
# 29/29 - 1s - 29ms/step - loss: 0.0271
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.02686
# 29/29 - 1s - 29ms/step - loss: 0.0272
# Epoch 21/100
#
# Epoch 21: loss improved from 0.02686 to 0.02669, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0267
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.02669
# 29/29 - 1s - 27ms/step - loss: 0.0269
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.02669
# 29/29 - 1s - 30ms/step - loss: 0.0273
# Epoch 24/100
#
# Epoch 24: loss improved from 0.02669 to 0.02504, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0250
# Epoch 25/100
#
# Epoch 25: loss improved from 0.02504 to 0.02438, saving model to ./save_model.keras
# 29/29 - 1s - 25ms/step - loss: 0.0244
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.02438
# 29/29 - 1s - 28ms/step - loss: 0.0245
# Epoch 27/100
#
# Epoch 27: loss improved from 0.02438 to 0.02382, saving model to ./save_model.keras
# 29/29 - 1s - 27ms/step - loss: 0.0238
# Epoch 28/100
#
# Epoch 28: loss improved from 0.02382 to 0.02352, saving model to ./save_model.keras
# 29/29 - 1s - 26ms/step - loss: 0.0235
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.02352
# 29/29 - 1s - 31ms/step - loss: 0.0235
# Epoch 30/100
#
# Epoch 30: loss improved from 0.02352 to 0.02270, saving model to ./save_model.keras
# 29/29 - 1s - 31ms/step - loss: 0.0227
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.02270
# 29/29 - 1s - 25ms/step - loss: 0.0235
# Epoch 32/100
#
# Epoch 32: loss improved from 0.02270 to 0.02244, saving model to ./save_model.keras
# 29/29 - 1s - 34ms/step - loss: 0.0224
# Epoch 33/100
#
# Epoch 33: loss improved from 0.02244 to 0.02226, saving model to ./save_model.keras
# 29/29 - 1s - 32ms/step - loss: 0.0223
# Epoch 34/100
#
# Epoch 34: loss improved from 0.02226 to 0.02192, saving model to ./save_model.keras
# 29/29 - 1s - 31ms/step - loss: 0.0219
# Epoch 35/100
#
# Epoch 35: loss improved from 0.02192 to 0.02164, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0216
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.02164
# 29/29 - 1s - 29ms/step - loss: 0.0216
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.02164
# 29/29 - 1s - 28ms/step - loss: 0.0221
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.02164
# 29/29 - 1s - 34ms/step - loss: 0.0228
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.02164
# 29/29 - 1s - 28ms/step - loss: 0.0231
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.02164
# 29/29 - 1s - 30ms/step - loss: 0.0220
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.02164
# 29/29 - 1s - 27ms/step - loss: 0.0217
# Epoch 42/100
#
# Epoch 42: loss improved from 0.02164 to 0.02084, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0208
# Epoch 43/100
#
# Epoch 43: loss improved from 0.02084 to 0.02071, saving model to ./save_model.keras
# 29/29 - 1s - 26ms/step - loss: 0.0207
# Epoch 44/100
#
# Epoch 44: loss improved from 0.02071 to 0.02012, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0201
# Epoch 45/100
#
# Epoch 45: loss improved from 0.02012 to 0.02000, saving model to ./save_model.keras
# 29/29 - 1s - 35ms/step - loss: 0.0200
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02000
# 29/29 - 1s - 37ms/step - loss: 0.0202
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.02000
# 29/29 - 1s - 33ms/step - loss: 0.0209
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.02000
# 29/29 - 1s - 26ms/step - loss: 0.0211
# Epoch 49/100
#
# Epoch 49: loss improved from 0.02000 to 0.01990, saving model to ./save_model.keras
# 29/29 - 1s - 26ms/step - loss: 0.0199
# Epoch 50/100
#
# Epoch 50: loss improved from 0.01990 to 0.01923, saving model to ./save_model.keras
# 29/29 - 1s - 34ms/step - loss: 0.0192
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01923
# 29/29 - 1s - 41ms/step - loss: 0.0200
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01923
# 29/29 - 1s - 36ms/step - loss: 0.0197
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01923
# 29/29 - 1s - 27ms/step - loss: 0.0201
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01923
# 29/29 - 1s - 31ms/step - loss: 0.0200
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01923
# 29/29 - 1s - 30ms/step - loss: 0.0197
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01923
# 29/29 - 1s - 29ms/step - loss: 0.0199
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01923
# 29/29 - 1s - 33ms/step - loss: 0.0199
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01923
# 29/29 - 1s - 31ms/step - loss: 0.0201
# Epoch 59/100
#
# Epoch 59: loss improved from 0.01923 to 0.01917, saving model to ./save_model.keras
# 29/29 - 1s - 32ms/step - loss: 0.0192
# Epoch 60/100
#
# Epoch 60: loss improved from 0.01917 to 0.01916, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0192
# Epoch 61/100
#
# Epoch 61: loss improved from 0.01916 to 0.01866, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0187
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01866
# 29/29 - 1s - 29ms/step - loss: 0.0191
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01866
# 29/29 - 1s - 30ms/step - loss: 0.0203
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01866
# 29/29 - 1s - 27ms/step - loss: 0.0190
# Epoch 65/100
#
# Epoch 65: loss improved from 0.01866 to 0.01850, saving model to ./save_model.keras
# 29/29 - 1s - 30ms/step - loss: 0.0185
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01850
# 29/29 - 1s - 29ms/step - loss: 0.0188
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01850
# 29/29 - 1s - 29ms/step - loss: 0.0191
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01850
# 29/29 - 1s - 27ms/step - loss: 0.0203
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01850
# 29/29 - 1s - 27ms/step - loss: 0.0211
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01850
# 29/29 - 1s - 24ms/step - loss: 0.0196
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01850
# 29/29 - 1s - 25ms/step - loss: 0.0187
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01850
# 29/29 - 1s - 27ms/step - loss: 0.0193
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01850
# 29/29 - 1s - 25ms/step - loss: 0.0190
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01850
# 29/29 - 1s - 26ms/step - loss: 0.0185
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01850
# 29/29 - 1s - 26ms/step - loss: 0.0188
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01850
# 29/29 - 1s - 26ms/step - loss: 0.0202
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01850
# 29/29 - 1s - 32ms/step - loss: 0.0187
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01850
# 29/29 - 1s - 30ms/step - loss: 0.0190
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01850
# 29/29 - 1s - 25ms/step - loss: 0.0186
# Epoch 80/100
#
# Epoch 80: loss improved from 0.01850 to 0.01812, saving model to ./save_model.keras
# 29/29 - 1s - 26ms/step - loss: 0.0181
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01812
# 29/29 - 1s - 28ms/step - loss: 0.0195
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01812
# 29/29 - 1s - 28ms/step - loss: 0.0196
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01812
# 29/29 - 1s - 34ms/step - loss: 0.0191
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01812
# 29/29 - 1s - 25ms/step - loss: 0.0188
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01812
# 29/29 - 1s - 28ms/step - loss: 0.0193
# Epoch 86/100
#
# Epoch 86: loss improved from 0.01812 to 0.01809, saving model to ./save_model.keras
# 29/29 - 1s - 29ms/step - loss: 0.0181
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01809
# 29/29 - 1s - 27ms/step - loss: 0.0191
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01809
# 29/29 - 1s - 29ms/step - loss: 0.0193
# Epoch 89/100
#
# Epoch 89: loss improved from 0.01809 to 0.01761, saving model to ./save_model.keras
# 29/29 - 1s - 28ms/step - loss: 0.0176
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01761
# 29/29 - 1s - 27ms/step - loss: 0.0178
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01761
# 29/29 - 1s - 29ms/step - loss: 0.0180
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01761
# 29/29 - 1s - 28ms/step - loss: 0.0190
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01761
# 29/29 - 1s - 30ms/step - loss: 0.0186
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01761
# 29/29 - 1s - 26ms/step - loss: 0.0197
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01761
# 29/29 - 1s - 27ms/step - loss: 0.0187
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01761
# 29/29 - 1s - 29ms/step - loss: 0.0188
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01761
# 29/29 - 1s - 29ms/step - loss: 0.0185
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01761
# 29/29 - 1s - 27ms/step - loss: 0.0186
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01761
# 29/29 - 1s - 28ms/step - loss: 0.0186
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01761
# 29/29 - 1s - 24ms/step - loss: 0.0188

# %%
#dữ liệu train
y_train = sc.inverse_transform(y_train) #giá thực
final_model = load_model("./save_model.keras")
y_train_predict = final_model.predict(x_train) #dự đoán giá đóng cửa trên tập đã train
y_train_predict = sc.inverse_transform(y_train_predict) #giá dự đoán
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step

# %% [markdown]
# # Bước 6: Tái sử dụng mô hình

# %%
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[1500:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# # Độ chính xác của mô hình

# %%
#lập biểu đồ so sánh
train_data1 = df1[50:1500]
test_data1 = df1[1500:]

plt.figure(figsize=(24,8))
plt.plot(df1,label='Giá thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Giá dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Giá dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh giá dự báo và giá thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Giá đóng cửa (VNĐ)') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12056\901534126.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data1['Dự đoán'] = y_train_predict #thêm dữ liệu
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12056\901534126.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['Dự đoán'] = y_test_predict #thêm dữ liệu

# %%
#r2
print('Độ phù hợp tập train:',r2_score(y_train,y_train_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):',mean_absolute_error(y_train,y_train_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập train:',mean_absolute_percentage_error(y_train,y_train_predict))
# Out:
# Độ phù hợp tập train: -7.993930646689298
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 3891653434.111828
# Phần trăm sai số tuyệt đối trung bình tập train: 0.9999886637277372

# %%
train_data1
# Out:
#             close       Dự đoán
# time
# 2013-03-20  26140  24118.417969
# 2013-03-21  25370  25249.248047
# 2013-03-22  25620  25459.828125
# 2013-03-25  25370  25468.867188
# 2013-03-26  25320  25302.785156
# ...           ...           ...
# 2019-01-03  58720  60123.359375
# 2019-01-04  58590  59026.914062
# 2019-01-07  59830  58343.652344
# 2019-01-08  61220  59081.285156
# 2019-01-09  62340  60539.421875
#
# [1450 rows x 2 columns]

# %%
#r2
print('Độ phù hợp tập test:',r2_score(y_test,y_test_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):',mean_absolute_error(y_test,y_test_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập test:',mean_absolute_percentage_error(y_test,y_test_predict))
# Out:
# Độ phù hợp tập test: 0.9826536650316384
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 1132.0706911057691
# Phần trăm sai số tuyệt đối trung bình tập test: 0.015447747489227679

# %%
test_data1
# Out:
#             close       Dự đoán
# time
# 2019-01-10  63300  61875.835938
# 2019-01-11  63090  62895.074219
# 2019-01-14  62060  62937.550781
# 2019-01-15  62610  62021.878906
# 2019-01-16  62820  62012.050781
# ...           ...           ...
# 2024-03-19  79700  80455.632812
# 2024-03-20  81000  79227.523438
# 2024-03-21  81000  80167.140625
# 2024-03-22  80500  80722.789062
# 2024-03-25  80400  80352.375000
#
# [1300 rows x 2 columns]

# %% [markdown]
# # Dự đoán giá tương lai và so sánh với giá ngày cuối

# %%
# Lấy ngày kế tiếp sau ngày cuối cùng trong tập dữ liệu để dự đoán
next_date = df['time'].iloc[-1] + pd.Timedelta(days=1)

# Chuyển đổi ngày kế tiếp sang dạng datetime
next_date = pd.to_datetime(next_date)

# Lấy giá trị của ngày cuối cùng trong tập dữ liệu
next_closing_price = np.array([df['close'].iloc[-1]])  # Lấy giá trị đóng cửa của ngày cuối cùng

# Chuẩn hóa giá trị của ngày cuối cùng
next_closing_price_normalized = sc.transform(next_closing_price.reshape(-1, 1))  # Chuyển thành mảng 2D

# Tạo dự đoán cho ngày kế tiếp bằng mô hình đã huấn luyện
x_next = np.array([sc_train[-50:, 0]])  # Lấy 50 giá đóng cửa gần nhất
x_next = np.reshape(x_next, (x_next.shape[0], x_next.shape[1], 1))
y_next_predict = final_model.predict(x_next)
y_next_predict = sc.inverse_transform(y_next_predict)

# Thêm dữ liệu dự đoán của ngày kế tiếp vào DataFrame
df_next = pd.DataFrame({'time': [next_date], 'close': [y_next_predict[0][0]]})
df1 = pd.concat([df1, df_next])

# Vẽ biểu đồ mới với dự đoán cho ngày kế tiếp
plt.figure(figsize=(15, 5))
plt.plot(df1['time'], df1['close'], label='Giá thực tế', color='red')
plt.plot(train_data1.index, train_data1['Dự đoán'], label='Giá dự đoán train', color='green')
plt.plot(test_data1.index, test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.scatter([next_date], [y_next_predict[0][0]], color='orange', label='Dự đoán ngày kế tiếp')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.title('So sánh giá dự báo và giá thực tế')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
# Lấy giá trị của ngày cuối cùng trong tập dữ liệu
actual_closing_price = df['close'].iloc[-1]

# Tạo DataFrame so sánh giá dự đoán với giá ngày cuối trong tập dữ liệu
comparison_df = pd.DataFrame({'time': [next_date], 'Giá dự đoán': [y_next_predict[0][0]], 'Giá ngày trước': [actual_closing_price]})

# In ra bảng so sánh
print(comparison_df)
# Out:
#         time  Giá dự đoán  Giá ngày trước
# 0 2024-03-26  80053.90625           80400
